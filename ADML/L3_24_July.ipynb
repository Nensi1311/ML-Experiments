# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("auto-mpg.csv")
df
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# ...

# %%
df.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70       1                ford torino

# %%
df.tail()
# Out:
#       mpg  cyl  displ  hp  weight  accel  yr  origin             name
# 387  27.0    4  140.0  86    2790   15.6  82       1  ford mustang gl
# 388  44.0    4   97.0  52    2130   24.6  82       2        vw pickup
# 389  32.0    4  135.0  84    2295   11.6  82       1    dodge rampage
# 390  28.0    4  120.0  79    2625   18.6  82       1      ford ranger
# 391  31.0    4  119.0  82    2720   19.4  82       1       chevy s-10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     392 non-null    float64
#  1   cyl     392 non-null    int64
#  2   displ   392 non-null    float64
#  3   hp      392 non-null    int64
#  4   weight  392 non-null    int64
#  5   accel   392 non-null    float64
#  6   yr      392 non-null    int64
#  7   origin  392 non-null    int64
#  8   name    392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB

# %%
df.shape
# Out:
# (392, 9)

# %%
df.describe()
# Out:
#               mpg         cyl       displ          hp       weight  \
# count  392.000000  392.000000  392.000000  392.000000   392.000000
# mean    23.445918    5.471939  194.411990  104.469388  2977.584184
# std      7.805007    1.705783  104.644004   38.491160   849.402560
# min      9.000000    3.000000   68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000  105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000  151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000  275.750000  126.000000  3614.750000
# max     46.600000    8.000000  455.000000  230.000000  5140.000000
#
#             accel          yr      origin
# count  392.000000  392.000000  392.000000
# mean    15.541327   75.979592    1.576531
# std      2.758864    3.683737    0.805518
# min      8.000000   70.000000    1.000000
# 25%     13.775000   73.000000    1.000000
# 50%     15.500000   76.000000    1.000000
# 75%     17.025000   79.000000    2.000000
# ...

# %%
df.describe(include="object")
# Out:
#                name
# count           392
# unique          301
# top     amc matador
# freq              5

# %%
df.isnull()
# Out:
#        mpg    cyl  displ     hp  weight  accel     yr  origin   name
# 0    False  False  False  False   False  False  False   False  False
# 1    False  False  False  False   False  False  False   False  False
# 2    False  False  False  False   False  False  False   False  False
# 3    False  False  False  False   False  False  False   False  False
# 4    False  False  False  False   False  False  False   False  False
# ..     ...    ...    ...    ...     ...    ...    ...     ...    ...
# 387  False  False  False  False   False  False  False   False  False
# 388  False  False  False  False   False  False  False   False  False
# 389  False  False  False  False   False  False  False   False  False
# 390  False  False  False  False   False  False  False   False  False
# 391  False  False  False  False   False  False  False   False  False
#
# [392 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# mpg       0
# cyl       0
# displ     0
# hp        0
# weight    0
# accel     0
# yr        0
# origin    0
# name      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['mpg', 'cyl', 'displ', 'hp', 'weight', 'accel', 'yr', 'origin', 'name'], dtype='object')

# %%
df['mpg'].value_counts()
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 31.9     1
# 16.9     1
# 18.2     1
# 22.3     1
# 44.0     1
# Name: mpg, Length: 127, dtype: int64

# %%
df['hp'].value_counts()
# Out:
# 150    22
# 90     20
# 88     19
# 110    18
# 100    17
#        ..
# 61      1
# 93      1
# 148     1
# 152     1
# 82      1
# Name: hp, Length: 93, dtype: int64

# %%
sns.boxplot(x="cyl", data=df)
# Out:
# <Axes: xlabel='cyl'>

# %%
sns.boxplot(x="displ", data=df)
# Out:
# <Axes: xlabel='displ'>

# %%
sns.boxplot(x="hp", data=df)
# Out:
# <Axes: xlabel='hp'>

# %%
hp_Q1 = df['hp'].quantile(0.25)
hp_Q3 = df['hp'].quantile(0.75)
hp_iqr = hp_Q3 - hp_Q1

# %%
upper_hp = hp_Q3 + 1.5 * hp_iqr
lower_hp = hp_Q1 - 1.5 * hp_iqr

# %%
df[df['hp'] > upper_hp]
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 6    14.0    8  454.0  220    4354    9.0  70       1
# 7    14.0    8  440.0  215    4312    8.5  70       1
# 8    14.0    8  455.0  225    4425   10.0  70       1
# 13   14.0    8  455.0  225    3086   10.0  70       1
# 25   10.0    8  360.0  215    4615   14.0  70       1
# 27   11.0    8  318.0  210    4382   13.5  70       1
# 66   11.0    8  429.0  208    4633   11.0  72       1
# 93   13.0    8  440.0  215    4735   11.0  73       1
# 94   12.0    8  455.0  225    4951   11.0  73       1
# 115  16.0    8  400.0  230    4278    9.5  73       1
#
#                              name
# 6                chevrolet impala
# 7               plymouth fury iii
# 8                pontiac catalina
# 13        buick estate wagon (sw)
# 25                      ford f250
# 27                     dodge d200
# 66                mercury marquis
# 93   chrysler new yorker brougham
# 94       buick electra 225 custom
# ...

# %%
df[df['hp'] < lower_hp]
# Out:
# Empty DataFrame
# Columns: [mpg, cyl, displ, hp, weight, accel, yr, origin, name]
# Index: []

# %%
new_df = df[(df['hp'] < upper_hp) & (df['hp'] > lower_hp)]

# %%
sns.boxplot(x="weight", data=df)
# Out:
# <Axes: xlabel='weight'>

# %%
sns.boxplot(x="accel", data=df)
# Out:
# <Axes: xlabel='accel'>

# %%
acce_Q1 = df['accel'].quantile(0.25)
acce_Q3 = df['accel'].quantile(0.75)
acce_iqr = acce_Q3 - acce_Q1

# %%
upper_acce = acce_Q3 + 1.5 * acce_iqr
lower_acce = acce_Q1 - 1.5 * acce_iqr

# %%
df[df['accel'] > upper_acce]
# Out:
#       mpg  cyl  displ  hp  weight  accel  yr  origin  \
# 58   23.0    4   97.0  54    2254   23.5  72       2
# 193  29.0    4   85.0  52    2035   22.2  76       1
# 194  24.5    4   98.0  60    2164   22.1  76       1
# 207  19.0    4  120.0  88    3270   21.9  76       2
# 297  27.2    4  141.0  71    3190   24.8  79       2
# 298  23.9    8  260.0  90    3420   22.2  79       1
# 324  43.4    4   90.0  48    2335   23.7  80       2
# 388  44.0    4   97.0  52    2130   24.6  82       2
#
#                                   name
# 58                   volkswagen type 3
# 193                 chevrolet chevette
# 194                    chevrolet woody
# 207                        peugeot 504
# 297                        peugeot 504
# 298  oldsmobile cutlass salon brougham
# 324                 vw dasher (diesel)
# 388                          vw pickup

# %%
df[df['accel'] < lower_acce]
# Out:
#      mpg  cyl  displ   hp  weight  accel  yr  origin                name
# 7   14.0    8  440.0  215    4312    8.5  70       1   plymouth fury iii
# 9   15.0    8  390.0  190    3850    8.5  70       1  amc ambassador dpl
# 11  14.0    8  340.0  160    3609    8.0  70       1  plymouth 'cuda 340

# %%
new_df = df[(df['accel'] < upper_acce) & (df['accel'] > lower_acce)]

# %%
sns.boxplot(x="accel", data=new_df)
# Out:
# <Axes: xlabel='accel'>

# %%
sns.boxplot(x="yr", data=df)
# Out:
# <Axes: xlabel='yr'>

# %%
sns.boxplot(x="origin", data=df)
# Out:
# <Axes: xlabel='origin'>

# %%
new_df
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 386  27.0    4  151.0   90    2950   17.3  82       1
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 386           chevrolet camaro
# 387            ford mustang gl
# ...

# %%
data = new_df.drop(['name'], axis=1)

# %%
data.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin
# 0  18.0    8  307.0  130    3504   12.0  70       1
# 1  15.0    8  350.0  165    3693   11.5  70       1
# 2  18.0    8  318.0  150    3436   11.0  70       1
# 3  16.0    8  304.0  150    3433   12.0  70       1
# 4  17.0    8  302.0  140    3449   10.5  70       1

# %%
data.shape
# Out:
# (381, 8)

# %%
X = data[['cyl', 'displ', 'hp', 'weight', 'yr']]
Y = data['mpg']

# %%
X.shape, Y.shape
# Out:
# ((381, 5), (381,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((266, 5), (115, 5))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
y_pred = lr.predict(X_test)

# %%
print("R2 score is: ",r2_score(Y_test, y_pred))
# Out:
# R2 score is:  0.8037918986044436
